# %%
torch.cuda.is_available()
# Out:
# False

# %%
# Clone the med-flamingo repository from GitHub
# !git clone https://github.com/Abir196/med-flamingo
# Out:
# Cloning into 'med-flamingo'...
# remote: Enumerating objects: 98, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 98 (delta 23), reused 17 (delta 17), pack-reused 70
# Unpacking objects: 100% (98/98), 468.18 KiB | 720.00 KiB/s, done.

# %%
# !pwd
# Out:
# /mnt/sohn2022/Andy/Med-Flamingo-Testing

# %%
import os
# Define the path to the requirements.txt file for the med-flamingo project
wd = '/mnt/sohn2022/Andy/Med-Flamingo-Testing'
requirements_path = f"{wd}/med-flamingo/requirements.txt"

# %%
# Install specific versions of PyTorch and torchvision
# !pip install torch==2.0.1 torchvision==0.15.2 -f https://download.pytorch.org/whl/cu117 -q # versions upgraded

# Install open_clip from a specific GitHub commit
# !pip install git+https://github.com/usuyama/open_clip.git@01a53cc46662d8b28da0c9d73271bfb8f6f4b20d -q

# Install specific versions of datasets, wandb, einops, einops_exts
# !pip install datasets==2.9.0 wandb==0.13.10 einops==0.6.0 einops_exts==0.0.4 -q

# Install h5py and ipykernel
# !pip install h5py ipykernel -q

# %%
# !pip install blinker
# !pip install backports.zoneinfo;python_version<"3.9"
# Out:
# Requirement already satisfied: blinker in /home/developer/anaconda3/envs/andy/lib/python3.11/site-packages (1.7.0)
# Collecting backports.zoneinfo
#   Using cached backports.zoneinfo-0.2.1.tar.gz (74 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: backports.zoneinfo
#   Building wheel for backports.zoneinfo (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Building wheel for backports.zoneinfo (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [55 lines of output]
#       /tmp/pip-build-env-sp42cckb/overlay/lib/python3.11/site-packages/setuptools/config/setupcfg.py:293: _DeprecatedConfig: Deprecated config in `setup.cfg`
#       !!
#
#               ********************************************************************************
#               The license_file parameter is deprecated, use license_files instead.
#
#               This deprecation is overdue, please update your project and remove deprecated
#               calls to avoid build errors in the future.
#
#               See https://setuptools.pypa.io/en/latest/userguide/declarative_config.html for details.
#               ********************************************************************************
#
#       !!
#         parsed = self.parsers.get(option_name, lambda x: x)(value)
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib.linux-x86_64-cpython-311
#       creating build/lib.linux-x86_64-cpython-311/backports
#       copying src/backports/__init__.py -> build/lib.linux-x86_64-cpython-311/backports
#       creating build/lib.linux-x86_64-cpython-311/backports/zoneinfo
#       copying src/backports/zoneinfo/_common.py -> build/lib.linux-x86_64-cpython-311/backports/zoneinfo
#       copying src/backports/zoneinfo/__init__.py -> build/lib.linux-x86_64-cpython-311/backports/zoneinfo
#       copying src/backports/zoneinfo/_version.py -> build/lib.linux-x86_64-cpython-311/backports/zoneinfo
#       copying src/backports/zoneinfo/_zoneinfo.py -> build/lib.linux-x86_64-cpython-311/backports/zoneinfo
#       copying src/backports/zoneinfo/_tzpath.py -> build/lib.linux-x86_64-cpython-311/backports/zoneinfo
#       running egg_info
#       writing src/backports.zoneinfo.egg-info/PKG-INFO
#       writing dependency_links to src/backports.zoneinfo.egg-info/dependency_links.txt
#       writing requirements to src/backports.zoneinfo.egg-info/requires.txt
#       writing top-level names to src/backports.zoneinfo.egg-info/top_level.txt
#       reading manifest file 'src/backports.zoneinfo.egg-info/SOURCES.txt'
#       reading manifest template 'MANIFEST.in'
#       warning: no files found matching '*.png' under directory 'docs'
#       warning: no files found matching '*.svg' under directory 'docs'
#       no previously-included directories found matching 'docs/_build'
#       no previously-included directories found matching 'docs/_output'
#       adding license file 'LICENSE'
#       adding license file 'licenses/LICENSE_APACHE'
#       writing manifest file 'src/backports.zoneinfo.egg-info/SOURCES.txt'
#       copying src/backports/zoneinfo/__init__.pyi -> build/lib.linux-x86_64-cpython-311/backports/zoneinfo
#       copying src/backports/zoneinfo/py.typed -> build/lib.linux-x86_64-cpython-311/backports/zoneinfo
#       running build_ext
#       building 'backports.zoneinfo._czoneinfo' extension
#       creating build/temp.linux-x86_64-cpython-311
#       creating build/temp.linux-x86_64-cpython-311/lib
#       gcc -pthread -B /home/developer/anaconda3/envs/andy/compiler_compat -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /home/developer/anaconda3/envs/andy/include -fPIC -O2 -isystem /home/developer/anaconda3/envs/andy/include -fPIC -I/home/developer/anaconda3/envs/andy/include/python3.11 -c lib/zoneinfo_module.c -o build/temp.linux-x86_64-cpython-311/lib/zoneinfo_module.o -std=c99
#       lib/zoneinfo_module.c: In function ‘zoneinfo_fromutc’:
#       lib/zoneinfo_module.c:600:19: error: ‘_PyLong_One’ undeclared (first use in this function); did you mean ‘_PyLong_New’?
#         600 |             one = _PyLong_One;
#             |                   ^~~~~~~~~~~
#             |                   _PyLong_New
#       lib/zoneinfo_module.c:600:19: note: each undeclared identifier is reported only once for each function it appears in
#       error: command '/usr/bin/gcc' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for backports.zoneinfo
# Failed to build backports.zoneinfo
# ERROR: Could not build wheels for backports.zoneinfo, which is required to install pyproject.toml-based projects
# /bin/bash: 3.9: No such file or directory

# %%
# Install additional requirements from the specified requirements.txt file
# !pip install -r {requirements_path} -q
# Out:
#   error: subprocess-exited-with-error
#
#   × Building wheel for backports.zoneinfo (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [55 lines of output]
#       /tmp/pip-build-env-d6fpjmwx/overlay/lib/python3.11/site-packages/setuptools/config/setupcfg.py:293: _DeprecatedConfig: Deprecated config in `setup.cfg`
#       !!
#
#               ********************************************************************************
#               The license_file parameter is deprecated, use license_files instead.
#
#               This deprecation is overdue, please update your project and remove deprecated
#               calls to avoid build errors in the future.
#
#               See https://setuptools.pypa.io/en/latest/userguide/declarative_config.html for details.
#               ********************************************************************************
#
#       !!
#         parsed = self.parsers.get(option_name, lambda x: x)(value)
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib.linux-x86_64-cpython-311
#       creating build/lib.linux-x86_64-cpython-311/backports
#       copying src/backports/__init__.py -> build/lib.linux-x86_64-cpython-311/backports
#       creating build/lib.linux-x86_64-cpython-311/backports/zoneinfo
#       copying src/backports/zoneinfo/_common.py -> build/lib.linux-x86_64-cpython-311/backports/zoneinfo
#       copying src/backports/zoneinfo/__init__.py -> build/lib.linux-x86_64-cpython-311/backports/zoneinfo
#       copying src/backports/zoneinfo/_version.py -> build/lib.linux-x86_64-cpython-311/backports/zoneinfo
#       copying src/backports/zoneinfo/_zoneinfo.py -> build/lib.linux-x86_64-cpython-311/backports/zoneinfo
#       copying src/backports/zoneinfo/_tzpath.py -> build/lib.linux-x86_64-cpython-311/backports/zoneinfo
#       running egg_info
#       writing src/backports.zoneinfo.egg-info/PKG-INFO
#       writing dependency_links to src/backports.zoneinfo.egg-info/dependency_links.txt
#       writing requirements to src/backports.zoneinfo.egg-info/requires.txt
#       writing top-level names to src/backports.zoneinfo.egg-info/top_level.txt
#       reading manifest file 'src/backports.zoneinfo.egg-info/SOURCES.txt'
#       reading manifest template 'MANIFEST.in'
#       warning: no files found matching '*.png' under directory 'docs'
#       warning: no files found matching '*.svg' under directory 'docs'
#       no previously-included directories found matching 'docs/_build'
#       no previously-included directories found matching 'docs/_output'
#       adding license file 'LICENSE'
#       adding license file 'licenses/LICENSE_APACHE'
#       writing manifest file 'src/backports.zoneinfo.egg-info/SOURCES.txt'
#       copying src/backports/zoneinfo/__init__.pyi -> build/lib.linux-x86_64-cpython-311/backports/zoneinfo
#       copying src/backports/zoneinfo/py.typed -> build/lib.linux-x86_64-cpython-311/backports/zoneinfo
#       running build_ext
#       building 'backports.zoneinfo._czoneinfo' extension
#       creating build/temp.linux-x86_64-cpython-311
#       creating build/temp.linux-x86_64-cpython-311/lib
#       gcc -pthread -B /home/developer/anaconda3/envs/andy/compiler_compat -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /home/developer/anaconda3/envs/andy/include -fPIC -O2 -isystem /home/developer/anaconda3/envs/andy/include -fPIC -I/home/developer/anaconda3/envs/andy/include/python3.11 -c lib/zoneinfo_module.c -o build/temp.linux-x86_64-cpython-311/lib/zoneinfo_module.o -std=c99
#       lib/zoneinfo_module.c: In function ‘zoneinfo_fromutc’:
#       lib/zoneinfo_module.c:600:19: error: ‘_PyLong_One’ undeclared (first use in this function); did you mean ‘_PyLong_New’?
#         600 |             one = _PyLong_One;
#             |                   ^~~~~~~~~~~
#             |                   _PyLong_New
#       lib/zoneinfo_module.c:600:19: note: each undeclared identifier is reported only once for each function it appears in
#       error: command '/usr/bin/gcc' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for backports.zoneinfo
# ERROR: Could not build wheels for backports.zoneinfo, which is required to install pyproject.toml-based projects

# %%
# Install open_flamingo, accelerate, bitsandbytes, and transformers libraries
# !pip install open_flamingo accelerate bitsandbytes transformers -q

# %% [markdown]
# # New Section

# %%
from huggingface_hub import hf_hub_download
import torch
import os
from open_flamingo import create_model_and_transforms
from accelerate import Accelerator
from einops import repeat
from PIL import Image
import sys

# Append paths for custom modules
sys.path.append(f'{wd}/med-flamingo/scripts')
sys.path.append(f'{wd}/med-flamingo')
from src.utils import FlamingoProcessor
from demo_utils import image_paths, clean_generation

# %%
# Initialize Accelerator
accelerator = Accelerator()  # Use hardware acceleration (GPU or TPU) based on availability
device = accelerator.device

print('Loading model..')

# Import create_model_and_transforms function
from open_flamingo import create_model_and_transforms

# Initialize the Flamingo model, image processor, and tokenizer
model, image_processor, tokenizer = create_model_and_transforms(
    clip_vision_encoder_path="ViT-L-14",
    clip_vision_encoder_pretrained="openai",
    lang_encoder_path="huggyllama/llama-7b",
    tokenizer_path="huggyllama/llama-7b",
    cross_attn_every_n_layers=4,
)
# Out:
# Loading model..
# 100%|███████████████████████████████████████| 933M/933M [00:25<00:00, 37.3MiB/s]
# Downloading (…)okenizer_config.json: 100%|█████| 700/700 [00:00<00:00, 4.07MB/s]
# Downloading tokenizer.model: 100%|███████████| 500k/500k [00:00<00:00, 25.8MB/s]
# Downloading (…)/main/tokenizer.json: 100%|█| 1.84M/1.84M [00:00<00:00, 7.51MB/s]
# Downloading (…)cial_tokens_map.json: 100%|█████| 411/411 [00:00<00:00, 1.81MB/s]
# Downloading (…)lve/main/config.json: 100%|█████| 594/594 [00:00<00:00, 3.47MB/s]
# Downloading (…)fetensors.index.json: 100%|█| 26.8k/26.8k [00:00<00:00, 65.2MB/s]
# Downloading shards:   0%|                                 | 0/2 [00:00<?, ?it/s]
# Downloading (…)of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# Downloading (…)of-00002.safetensors:   0%| | 10.5M/9.98G [00:00<01:41, 97.8MB/s]
# Downloading (…)of-00002.safetensors:   0%| | 21.0M/9.98G [00:00<01:43, 95.9MB/s]
# Downloading (…)of-00002.safetensors:   0%| | 31.5M/9.98G [00:00<01:41, 97.6MB/s]
# Downloading (…)of-00002.safetensors:   1%|  | 52.4M/9.98G [00:00<01:35, 104MB/s]
# Downloading (…)of-00002.safetensors:   1%|  | 62.9M/9.98G [00:00<01:34, 105MB/s]
# Downloading (…)of-00002.safetensors:   1%|  | 73.4M/9.98G [00:00<01:35, 104MB/s]
# Downloading (…)of-00002.safetensors:   1%|  | 94.4M/9.98G [00:00<01:32, 107MB/s]
# Downloading (…)of-00002.safetensors:   1%|   | 115M/9.98G [00:01<01:33, 106MB/s]
# Downloading (…)of-00002.safetensors:   1%|   | 136M/9.98G [00:01<01:32, 106MB/s]
# Downloading (…)of-00002.safetensors:   2%|   | 157M/9.98G [00:01<01:30, 108MB/s]
# Downloading (…)of-00002.safetensors:   2%|   | 178M/9.98G [00:01<01:28, 110MB/s]
# Downloading (…)of-00002.safetensors:   2%|   | 199M/9.98G [00:01<01:27, 111MB/s]
# Downloading (…)of-00002.safetensors:   2%|   | 220M/9.98G [00:02<01:27, 112MB/s]
# Downloading (…)of-00002.safetensors:   2%|   | 241M/9.98G [00:02<01:26, 112MB/s]
# Downloading (…)of-00002.safetensors:   3%|   | 262M/9.98G [00:02<01:26, 112MB/s]
# Downloading (…)of-00002.safetensors:  98%|█▉| 9.79G/9.98G [01:32<00:01, 110MB/s]
# Downloading (…)of-00002.safetensors:  98%|█▉| 9.81G/9.98G [01:32<00:01, 108MB/s]
# Downloading (…)of-00002.safetensors:  99%|█▉| 9.84G/9.98G [01:32<00:01, 110MB/s]
# Downloading (…)of-00002.safetensors:  99%|█▉| 9.86G/9.98G [01:32<00:01, 110MB/s]
# Downloading (…)of-00002.safetensors:  99%|█▉| 9.88G/9.98G [01:32<00:00, 108MB/s]
# Downloading (…)of-00002.safetensors:  99%|█▉| 9.90G/9.98G [01:33<00:00, 109MB/s]
# Downloading (…)of-00002.safetensors:  99%|█▉| 9.92G/9.98G [01:33<00:00, 109MB/s]
# Downloading (…)of-00002.safetensors: 100%|█▉| 9.94G/9.98G [01:33<00:00, 109MB/s]
# Downloading (…)of-00002.safetensors: 100%|█▉| 9.96G/9.98G [01:33<00:00, 109MB/s]
# Downloading (…)of-00002.safetensors: 100%|██| 9.98G/9.98G [01:33<00:00, 106MB/s]
# Downloading shards:  50%|████████████▌            | 1/2 [01:34<01:34, 94.00s/it]
# Downloading (…)of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Downloading (…)of-00002.safetensors:   1%|  | 21.0M/3.50G [00:00<00:32, 106MB/s]
# Downloading (…)of-00002.safetensors:   1%|  | 41.9M/3.50G [00:00<00:31, 109MB/s]
# Downloading (…)of-00002.safetensors:   2%|  | 62.9M/3.50G [00:00<00:31, 109MB/s]
# Downloading (…)of-00002.safetensors:   2%|  | 83.9M/3.50G [00:00<00:30, 112MB/s]
# Downloading (…)of-00002.safetensors:   3%|   | 105M/3.50G [00:00<00:30, 110MB/s]
# Downloading (…)of-00002.safetensors:   4%|   | 126M/3.50G [00:01<00:30, 111MB/s]
# Downloading (…)of-00002.safetensors:   4%|▏  | 147M/3.50G [00:01<00:30, 108MB/s]
# Downloading (…)of-00002.safetensors:   5%|▏  | 168M/3.50G [00:01<00:30, 110MB/s]
# Downloading (…)of-00002.safetensors:   5%|▏  | 189M/3.50G [00:01<00:29, 111MB/s]
# Downloading (…)of-00002.safetensors:   6%|▏  | 210M/3.50G [00:01<00:29, 111MB/s]
# Downloading (…)of-00002.safetensors:   7%|▏  | 231M/3.50G [00:02<00:29, 109MB/s]
# Downloading (…)of-00002.safetensors:   7%|▏ | 252M/3.50G [00:02<00:38, 83.5MB/s]
# Downloading (…)of-00002.safetensors:   8%|▏ | 273M/3.50G [00:02<00:36, 89.4MB/s]
# Downloading (…)of-00002.safetensors:   8%|▏ | 283M/3.50G [00:02<00:35, 90.7MB/s]
# Downloading (…)of-00002.safetensors:   9%|▏ | 304M/3.50G [00:02<00:32, 99.0MB/s]
# Downloading (…)of-00002.safetensors:   9%|▎  | 325M/3.50G [00:03<00:30, 103MB/s]
# Downloading (…)of-00002.safetensors:  10%|▎  | 346M/3.50G [00:03<00:29, 106MB/s]
# Downloading (…)of-00002.safetensors:  10%|▎  | 367M/3.50G [00:03<00:29, 108MB/s]
# Downloading (…)of-00002.safetensors:  11%|▎  | 388M/3.50G [00:03<00:28, 108MB/s]
# Downloading (…)of-00002.safetensors:  12%|▎  | 409M/3.50G [00:03<00:28, 110MB/s]
# Downloading (…)of-00002.safetensors:  30%|▌ | 1.06G/3.50G [00:09<00:21, 112MB/s]
# Downloading (…)of-00002.safetensors:  31%|▌ | 1.08G/3.50G [00:09<00:21, 111MB/s]
# Downloading (…)of-00002.safetensors:  31%|▋ | 1.10G/3.50G [00:10<00:21, 110MB/s]
# Downloading (…)of-00002.safetensors:  32%|▋ | 1.12G/3.50G [00:10<00:21, 110MB/s]
# Downloading (…)of-00002.safetensors:  33%|▋ | 1.14G/3.50G [00:10<00:21, 109MB/s]
# Downloading (…)of-00002.safetensors:  33%|▋ | 1.16G/3.50G [00:10<00:21, 108MB/s]
# Downloading (…)of-00002.safetensors:  34%|▋ | 1.18G/3.50G [00:10<00:21, 108MB/s]
# Downloading (…)of-00002.safetensors:  34%|▋ | 1.21G/3.50G [00:11<00:21, 108MB/s]
# Downloading (…)of-00002.safetensors:  35%|▋ | 1.23G/3.50G [00:11<00:20, 108MB/s]
# Downloading (…)of-00002.safetensors:  36%|▋ | 1.25G/3.50G [00:11<00:20, 108MB/s]
# Downloading (…)of-00002.safetensors:  36%|▋ | 1.27G/3.50G [00:11<00:20, 107MB/s]
# Downloading (…)of-00002.safetensors:  37%|▋ | 1.29G/3.50G [00:11<00:20, 107MB/s]
# Downloading (…)of-00002.safetensors:  37%|▋ | 1.31G/3.50G [00:12<00:20, 109MB/s]
# Downloading (…)of-00002.safetensors:  38%|▊ | 1.33G/3.50G [00:12<00:20, 108MB/s]
# Downloading (…)of-00002.safetensors:  39%|▊ | 1.35G/3.50G [00:12<00:19, 109MB/s]
# Downloading (…)of-00002.safetensors:  39%|▊ | 1.37G/3.50G [00:12<00:19, 109MB/s]
# Downloading (…)of-00002.safetensors:  40%|▊ | 1.39G/3.50G [00:12<00:19, 107MB/s]
# Downloading (…)of-00002.safetensors:  40%|▊ | 1.42G/3.50G [00:13<00:19, 107MB/s]
# Downloading (…)of-00002.safetensors:  41%|▊ | 1.44G/3.50G [00:13<00:19, 108MB/s]
# Downloading (…)of-00002.safetensors:  42%|▊ | 1.46G/3.50G [00:13<00:18, 108MB/s]
# Downloading (…)of-00002.safetensors:  42%|▊ | 1.48G/3.50G [00:13<00:18, 109MB/s]
# Downloading (…)of-00002.safetensors:  43%|▊ | 1.50G/3.50G [00:13<00:18, 108MB/s]
# Downloading (…)of-00002.safetensors:  43%|▊ | 1.52G/3.50G [00:13<00:18, 108MB/s]
# Downloading (…)of-00002.safetensors:  44%|▉ | 1.54G/3.50G [00:14<00:17, 110MB/s]
# Downloading (…)of-00002.safetensors:  45%|▉ | 1.56G/3.50G [00:14<00:17, 110MB/s]
# Downloading (…)of-00002.safetensors:  45%|▉ | 1.58G/3.50G [00:14<00:17, 110MB/s]
# Downloading (…)of-00002.safetensors:  46%|▉ | 1.60G/3.50G [00:14<00:17, 110MB/s]
# Downloading (…)of-00002.safetensors:  46%|▉ | 1.63G/3.50G [00:14<00:16, 110MB/s]
# Downloading (…)of-00002.safetensors:  47%|▍| 1.65G/3.50G [00:15<00:22, 83.5MB/s]
# Downloading (…)of-00002.safetensors:  47%|▍| 1.66G/3.50G [00:15<00:21, 85.6MB/s]
# Downloading (…)of-00002.safetensors:  48%|▍| 1.67G/3.50G [00:15<00:20, 88.1MB/s]
# Downloading (…)of-00002.safetensors:  48%|▍| 1.69G/3.50G [00:15<00:19, 94.2MB/s]
# Downloading (…)of-00002.safetensors:  49%|▍| 1.71G/3.50G [00:15<00:17, 99.9MB/s]
# Downloading (…)of-00002.safetensors:  49%|▉ | 1.73G/3.50G [00:16<00:16, 104MB/s]
# Downloading (…)of-00002.safetensors:  50%|█ | 1.75G/3.50G [00:16<00:16, 106MB/s]
# Downloading (…)of-00002.safetensors:  51%|█ | 1.77G/3.50G [00:16<00:16, 103MB/s]
# Downloading (…)of-00002.safetensors:  51%|█ | 1.79G/3.50G [00:16<00:15, 107MB/s]
# Downloading (…)of-00002.safetensors:  52%|█ | 1.81G/3.50G [00:16<00:15, 109MB/s]
# Downloading (…)of-00002.safetensors:  52%|█ | 1.84G/3.50G [00:17<00:15, 110MB/s]
# Downloading (…)of-00002.safetensors:  53%|█ | 1.86G/3.50G [00:17<00:15, 109MB/s]
# Downloading (…)of-00002.safetensors:  54%|█ | 1.88G/3.50G [00:17<00:14, 110MB/s]
# Downloading (…)of-00002.safetensors:  54%|█ | 1.90G/3.50G [00:17<00:14, 109MB/s]
# Downloading (…)of-00002.safetensors:  55%|█ | 1.92G/3.50G [00:17<00:14, 111MB/s]
# Downloading (…)of-00002.safetensors:  55%|█ | 1.94G/3.50G [00:18<00:14, 111MB/s]
# Downloading (…)of-00002.safetensors:  56%|█ | 1.96G/3.50G [00:18<00:14, 109MB/s]
# Downloading (…)of-00002.safetensors:  57%|█▏| 1.98G/3.50G [00:18<00:14, 108MB/s]
# Downloading (…)of-00002.safetensors:  57%|█▏| 2.00G/3.50G [00:18<00:14, 106MB/s]
# Downloading (…)of-00002.safetensors:  58%|█▏| 2.02G/3.50G [00:18<00:14, 102MB/s]
# Downloading (…)of-00002.safetensors:  58%|█▏| 2.04G/3.50G [00:19<00:14, 104MB/s]
# Downloading (…)of-00002.safetensors:  59%|█▏| 2.06G/3.50G [00:19<00:13, 104MB/s]
# Downloading (…)of-00002.safetensors:  59%|█▏| 2.07G/3.50G [00:19<00:13, 103MB/s]
# Downloading (…)of-00002.safetensors:  59%|█▏| 2.08G/3.50G [00:19<00:13, 102MB/s]
# Downloading (…)of-00002.safetensors:  60%|▌| 2.09G/3.50G [00:19<00:14, 99.4MB/s]
# Downloading (…)of-00002.safetensors:  60%|█▏| 2.11G/3.50G [00:19<00:13, 104MB/s]
# Downloading (…)of-00002.safetensors:  61%|█▏| 2.12G/3.50G [00:19<00:13, 102MB/s]
# Downloading (…)of-00002.safetensors:  61%|█▏| 2.13G/3.50G [00:19<00:13, 102MB/s]
# Downloading (…)of-00002.safetensors:  61%|█▏| 2.14G/3.50G [00:19<00:13, 102MB/s]
# Downloading (…)of-00002.safetensors:  62%|█▏| 2.16G/3.50G [00:20<00:12, 109MB/s]
# Downloading (…)of-00002.safetensors:  62%|█▏| 2.18G/3.50G [00:20<00:12, 109MB/s]
# Downloading (…)of-00002.safetensors:  63%|█▎| 2.20G/3.50G [00:20<00:11, 110MB/s]
# Downloading (…)of-00002.safetensors:  64%|█▎| 2.22G/3.50G [00:20<00:11, 110MB/s]
# Downloading (…)of-00002.safetensors:  64%|█▎| 2.24G/3.50G [00:20<00:11, 110MB/s]
# Downloading (…)of-00002.safetensors:  65%|█▎| 2.26G/3.50G [00:21<00:11, 110MB/s]
# Downloading (…)of-00002.safetensors:  65%|█▎| 2.29G/3.50G [00:21<00:10, 111MB/s]
# Downloading (…)of-00002.safetensors:  66%|█▎| 2.31G/3.50G [00:21<00:10, 111MB/s]
# Downloading (…)of-00002.safetensors:  67%|█▎| 2.33G/3.50G [00:21<00:10, 110MB/s]
# Downloading (…)of-00002.safetensors:  67%|█▎| 2.35G/3.50G [00:21<00:10, 109MB/s]
# Downloading (…)of-00002.safetensors:  68%|█▎| 2.37G/3.50G [00:22<00:10, 110MB/s]
# Downloading (…)of-00002.safetensors:  68%|█▎| 2.39G/3.50G [00:22<00:10, 110MB/s]
# Downloading (…)of-00002.safetensors:  69%|█▍| 2.41G/3.50G [00:22<00:09, 110MB/s]
# Downloading (…)of-00002.safetensors:  69%|█▍| 2.43G/3.50G [00:22<00:09, 112MB/s]
# Downloading (…)of-00002.safetensors:  70%|█▍| 2.45G/3.50G [00:22<00:09, 112MB/s]
# Downloading (…)of-00002.safetensors:  71%|█▍| 2.47G/3.50G [00:22<00:09, 112MB/s]
# Downloading (…)of-00002.safetensors:  71%|█▍| 2.50G/3.50G [00:23<00:08, 112MB/s]
# Downloading (…)of-00002.safetensors:  72%|█▍| 2.52G/3.50G [00:23<00:08, 113MB/s]
# Downloading (…)of-00002.safetensors:  72%|█▍| 2.54G/3.50G [00:23<00:08, 113MB/s]
# Downloading (…)of-00002.safetensors:  73%|█▍| 2.56G/3.50G [00:23<00:08, 112MB/s]
# Downloading (…)of-00002.safetensors:  74%|█▍| 2.58G/3.50G [00:23<00:08, 112MB/s]
# Downloading (…)of-00002.safetensors:  74%|█▍| 2.60G/3.50G [00:24<00:07, 113MB/s]
# Downloading (…)of-00002.safetensors:  75%|█▍| 2.62G/3.50G [00:24<00:07, 112MB/s]
# Downloading (…)of-00002.safetensors:  75%|█▌| 2.64G/3.50G [00:24<00:07, 111MB/s]
# Downloading (…)of-00002.safetensors:  76%|█▌| 2.66G/3.50G [00:24<00:07, 113MB/s]
# Downloading (…)of-00002.safetensors:  77%|█▌| 2.68G/3.50G [00:24<00:07, 114MB/s]
# Downloading (…)of-00002.safetensors:  77%|█▌| 2.71G/3.50G [00:25<00:07, 113MB/s]
# Downloading (…)of-00002.safetensors:  78%|█▌| 2.73G/3.50G [00:25<00:06, 114MB/s]
# Downloading (…)of-00002.safetensors:  78%|▊| 2.75G/3.50G [00:25<00:08, 85.0MB/s]
# Downloading (…)of-00002.safetensors:  79%|▊| 2.77G/3.50G [00:25<00:08, 91.0MB/s]
# Downloading (…)of-00002.safetensors:  80%|▊| 2.79G/3.50G [00:25<00:07, 96.3MB/s]
# Downloading (…)of-00002.safetensors:  80%|█▌| 2.81G/3.50G [00:26<00:06, 101MB/s]
# Downloading (…)of-00002.safetensors:  81%|█▌| 2.83G/3.50G [00:26<00:06, 105MB/s]
# Downloading (…)of-00002.safetensors:  81%|█▋| 2.85G/3.50G [00:26<00:06, 107MB/s]
# Downloading (…)of-00002.safetensors:  82%|█▋| 2.87G/3.50G [00:26<00:05, 107MB/s]
# Downloading (…)of-00002.safetensors:  83%|█▋| 2.89G/3.50G [00:26<00:05, 108MB/s]
# Downloading (…)of-00002.safetensors:  83%|█▋| 2.92G/3.50G [00:27<00:05, 110MB/s]
# Downloading (…)of-00002.safetensors:  84%|█▋| 2.94G/3.50G [00:27<00:05, 112MB/s]
# Downloading (…)of-00002.safetensors:  84%|█▋| 2.96G/3.50G [00:27<00:04, 111MB/s]
# Downloading (…)of-00002.safetensors:  85%|█▋| 2.98G/3.50G [00:27<00:04, 113MB/s]
# Downloading (…)of-00002.safetensors:  86%|█▋| 3.00G/3.50G [00:27<00:04, 113MB/s]
# Downloading (…)of-00002.safetensors:  86%|█▋| 3.02G/3.50G [00:28<00:04, 113MB/s]
# Downloading (…)of-00002.safetensors:  87%|█▋| 3.04G/3.50G [00:28<00:04, 114MB/s]
# Downloading (…)of-00002.safetensors:  87%|█▋| 3.06G/3.50G [00:28<00:03, 113MB/s]
# Downloading (…)of-00002.safetensors:  88%|█▊| 3.08G/3.50G [00:28<00:03, 113MB/s]
# Downloading (…)of-00002.safetensors:  89%|█▊| 3.10G/3.50G [00:28<00:03, 113MB/s]
# Downloading (…)of-00002.safetensors:  89%|█▊| 3.12G/3.50G [00:28<00:03, 113MB/s]
# Downloading (…)of-00002.safetensors:  90%|█▊| 3.15G/3.50G [00:29<00:03, 113MB/s]
# Downloading (…)of-00002.safetensors:  90%|█▊| 3.17G/3.50G [00:29<00:02, 113MB/s]
# Downloading (…)of-00002.safetensors:  91%|█▊| 3.19G/3.50G [00:29<00:02, 112MB/s]
# Downloading (…)of-00002.safetensors:  92%|█▊| 3.21G/3.50G [00:29<00:02, 114MB/s]
# Downloading (…)of-00002.safetensors:  92%|█▊| 3.23G/3.50G [00:29<00:02, 114MB/s]
# Downloading (…)of-00002.safetensors:  93%|█▊| 3.25G/3.50G [00:30<00:02, 114MB/s]
# Downloading (…)of-00002.safetensors:  93%|█▊| 3.27G/3.50G [00:30<00:02, 112MB/s]
# Downloading (…)of-00002.safetensors:  94%|█▉| 3.29G/3.50G [00:30<00:01, 114MB/s]
# Downloading (…)of-00002.safetensors:  95%|█▉| 3.31G/3.50G [00:30<00:01, 113MB/s]
# Downloading (…)of-00002.safetensors:  95%|█▉| 3.33G/3.50G [00:30<00:01, 114MB/s]
# Downloading (…)of-00002.safetensors:  96%|█▉| 3.36G/3.50G [00:30<00:01, 114MB/s]
# Downloading (…)of-00002.safetensors:  96%|█▉| 3.38G/3.50G [00:31<00:01, 113MB/s]
# Downloading (…)of-00002.safetensors:  97%|█▉| 3.40G/3.50G [00:31<00:00, 113MB/s]
# Downloading (…)of-00002.safetensors:  98%|█▉| 3.42G/3.50G [00:31<00:00, 114MB/s]
# Downloading (…)of-00002.safetensors:  98%|█▉| 3.44G/3.50G [00:31<00:00, 115MB/s]
# Downloading (…)of-00002.safetensors:  99%|█▉| 3.46G/3.50G [00:31<00:00, 113MB/s]
# Downloading (…)of-00002.safetensors:  99%|█▉| 3.48G/3.50G [00:32<00:00, 114MB/s]
# Downloading (…)of-00002.safetensors: 100%|██| 3.50G/3.50G [00:32<00:00, 108MB/s]
# Downloading shards: 100%|█████████████████████████| 2/2 [02:06<00:00, 63.18s/it]
# Loading checkpoint shards: 100%|██████████████████| 2/2 [00:01<00:00,  1.36it/s]
# Downloading (…)neration_config.json: 100%|█████| 137/137 [00:00<00:00, 1.52MB/s]
# Flamingo model initialized with 1309919248 trainable parameters

# %%
# Import necessary libraries
from huggingface_hub import hf_hub_download
import torch

# Download the Med-Flamingo checkpoint from the Hugging Face Hub
checkpoint_path = hf_hub_download("med-flamingo/med-flamingo", "model.pt")
print(f'Downloaded Med-Flamingo checkpoint to {checkpoint_path}')

# Load the downloaded checkpoint using PyTorch
med_flamingo_checkpoint = torch.load(checkpoint_path, 
                                     map_location="cuda" if torch.cuda.is_available() else "cpu")
torch.cuda.is_available()
# Out:
# Downloaded Med-Flamingo checkpoint to /home/developer/.cache/huggingface/hub/models--med-flamingo--med-flamingo/snapshots/7243cd83bd426ceade9c4de9844cc5e5f3ff75e0/model.pt
# False

# %%
# Load the Med-Flamingo checkpoint into the model (not enforcing strict compatibility)
model.load_state_dict(med_flamingo_checkpoint, strict=False)

# Initialize the FlamingoProcessor using the tokenizer and image_processor
processor = FlamingoProcessor(tokenizer, image_processor)

# %%
# Select only the first 2 image paths
# image_paths = image_paths[:2]

image_paths = [
    f"{wd}/med-flamingo/img/synpic21044.jpg",
    f"{wd}/med-flamingo/img/synpic30324.jpg",
    f"{wd}/med-flamingo/img/synpic47964.jpg",
    f"{wd}/med-flamingo/img/synpic50962.jpg",
    f"{wd}/med-flamingo/img/synpic52767.jpg",
    f"{wd}/med-flamingo/img/synpic54802.jpg",
    f"{wd}/med-flamingo/img/synpic57813.jpg",
]

# Prepare the model using the Accelerator
model = accelerator.prepare(model)
is_main_process = accelerator.is_main_process
model.eval()

"""
Step 1: Load images
"""
# Load demo images using PIL and store in a list
# demo_images = [Image.open(path) for path in image_paths]
demo_images = [Image.open(path) for path in image_paths]

# %%
Image.open(f"{wd}/med-flamingo/img/synpic52767.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x840>

# %%
"""
Step 2: Define multimodal few-shot prompt
"""

# Define a few-shot prompt containing text and  placeholders
prompt = "You are a helpful medical assistant. You are being provided with images, a question about the image and an answer. Follow the examples and answer the last question. Question: What is/are the structure near/in the middle of the brain? Answer: pons.Question: Is there evidence of a right apical pneumothorax on this chest x-ray? Answer: yes.Question: Is/Are there air in the patient's peritoneal cavity? Answer: no.Question: Does the heart appear enlarged? Answer: yes.Question: What side are the infarcts located? Answer: bilateral.Question: Which image modality is this? Answer: mr flair.Question: What is the most likely diagnosis?"
# prompt = "You are a helpful medical assistant. Describe the image"
# prompt = "What is the most likely diagnosis?"
"""
Step 3: Preprocess data
"""
print('Preprocess data')

# Preprocess demo images using the FlamingoProcessor
pixels = processor.preprocess_images(demo_images)

pixels = repeat(pixels, 'N c h w -> b N T c h w', b=1, T=1)

# Encode the text prompt using the FlamingoProcessor
tokenized_data = processor.encode_text(prompt)
# Out:
# Preprocess data

# %%
"""
Step 4: Generate response
"""

# Generate a response using the multimodal few-shot prompt
print('Generate from multimodal few-shot prompt')

# Use mixed-precision training context for improved performance
with torch.autocast('cuda' if torch.cuda.is_available() else 'cpu', torch.float16):

    # Generate text using the model
    generated_text = model.generate(
        vision_x=pixels.to(device),  # Convert images to the device
        lang_x=tokenized_data["input_ids"].to(device),  # Convert text input to the device
        attention_mask=tokenized_data["attention_mask"].to(device),  # Convert attention mask to the device
        max_new_tokens=50,  # Limit the maximum number of new tokens in the generated response
    )

# Decode the generated text using the processor's tokenizer
response = processor.tokenizer.decode(generated_text[0])

# Clean up the generated response
response = clean_generation(response)

# Print the cleaned response
print(f'{response=}')
# Out:
# Generate from multimodal few-shot prompt
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[27], line 9
#       6 print('Generate from multimodal few-shot prompt')
#       8 # Use mixed-precision training context for improved performance
# ----> 9 with torch.autocast('cuda' if torch.cuda.is_available() else 'cpu', torch.float16):
#      10
#      11     # Generate text using the model
#      12     generated_text = model.generate(
#      13         vision_x=pixels.to(device),  # Convert images to the device
#      14         lang_x=tokenized_data["input_ids"].to(device),  # Convert text input to the device
#      15         attention_mask=tokenized_data["attention_mask"].to(device),  # Convert attention mask to the device
#      16         max_new_tokens=50,  # Limit the maximum number of new tokens in the generated response
#      17     )
#      19 # Decode the generated text using the processor's tokenizer
#
# File ~/anaconda3/envs/andy/lib/python3.11/site-packages/torch/amp/autocast_mode.py:247, in autocast.__enter__(self)
#     245     self.prev_fastdtype = torch.get_autocast_cpu_dtype()
#     246     torch.set_autocast_cpu_enabled(self._enabled)
# --> 247     torch.set_autocast_cpu_dtype(self.fast_dtype)  # type: ignore[arg-type]
#     248     torch.autocast_increment_nesting()
#     249 elif self.device == 'xpu':
#
# RuntimeError: Currently, AutocastCPU only support Bfloat16 as the autocast_cpu_dtype

# %%
print(f'{response.strip("<s>")}\n')
# Out:
#  You are a helpful medical assistant. You are being provided with images, a question about the image and an answer. Follow the examples and answer the last question.  Question: What is/are the structure near/in the middle of the brain? Answer: pons. Question: Is there evidence of a right apical pneumothorax on this chest x-ray? Answer: yes. Question: Is/Are there air in the patient's peritoneal cavity? Answer: no. Question: Does the heart appear enlarged? Answer: yes. Question: What side are the infarcts located? Answer: bilateral. Question: Which image modality is this? Answer: mr flair. Question: What is the most likely diagnosis? Answer: metastatic disease.
#  1. What is the structure near the middle of the brain?
#  2. Is there evidence of a right apical pneumothorax on this chest x-ray?
#  3

# %%
# Clear GPU memory cache to free up memory
torch.cuda.empty_cache()

# Move the perceiver and vision_encoder of the model to GPU
model.perceiver.cuda()
model.vision_encoder.cuda()

# Convert the gated_cross_attn_layers of the lang_encoder to float16 and move to GPU
model.lang_encoder.gated_cross_attn_layers.to(torch.float16).cuda()

# Clear GPU memory cache again after moving tensors to GPU
torch.cuda.empty_cache()

# %%
import gc  # Import the garbage collection module

# Collect and free up unused memory
gc.collect()
# Out:
# 0
